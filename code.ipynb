# %%
import torch
import torchaudio
import numpy as np
import pandas as pd
import librosa

SAMPLE_RATE = 16000

# %%
def round_up_audio(audio):
    
    rem = audio.shape[0]%SAMPLE_RATE
    zero_len = SAMPLE_RATE-rem
    added_arr = np.zeros(zero_len, audio.dtype)
    ext_audio = np.concatenate((audio, added_arr), axis=None)

    return ext_audio

# %%
audio_sample = '../../LibriVox_Kaggle/achtgesichterambiwasse/achtgesichterambiwasse_0003.wav'
bg = '../../LibriVox_Kaggle/BGnoise/restaurant2.wav'

'''wav, sr = torchaudio.load(audio_sample)
bg_wav, sr2 = torchaudio.load(bg)
'''
wav, sr = librosa.load(audio_sample, sr=16000)


wav = round_up_audio(wav)
wav /= np.max(np.abs(wav), axis=0)
duration = wav.shape[0]/sr

bg_wav, sr2 = librosa.load(bg, sr=16000)

(duration), SAMPLE_RATE-wav.shape[0]%sr, wav.mean()
# Out:
# (10.0, 16000, -5.8183086e-06)

# %%
from IPython.display import display, Audio

display(Audio(wav, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os

for dirpath, dirnames, files in os.walk('../../LibriVox_Kaggle'):
    print(dirnames)
# Out:
# ['achtgesichterambiwasse', 'meisterfloh', 'serapionsbruederauswahl', 'RIR', 'BGnoise', 'ScribosermoModel', 'clean_text', 'outIR', 'outN1N2', 'random', 'outBg', '__pycache__']
# ['ir_noise', 'bg_noise', 'n1n2']
# ['formatted']
# []
# ['formatted']
# []
# ['formatted']
# []
# ['formatted', 'bg_noise', 'ir_noise', 'n1n2']
# []
# ['formatted']
# []
# ['formatted']
# []
# ['formatted']
# []
# ['formatted', 'bg_noise', 'ir_noise', 'n1n2']
# []
# ['formatted']
# []
# ['formatted']
# []
# ['formatted']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
